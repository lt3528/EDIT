// %% [markdown]
// # Funkcije prvog reda, I. dio
// ### EDIT napredni tečaj, 3. predavanje
//
// U ovoj vježbi prolazimo kroz najčešće metode za rad s nizovima: `forEach`, `map`, `some` i `find`.
//
// **Upute:**
// 1. Pročitaj zadatak.
// 2. Upiši svoj kod u ćeliju ispod zadatka.
// 3. Pokreni izvršavanje koda pristiskom na ikonu 'Play' koja se nalazi s lijeve strane ćelije.

// %% [markdown]
// ---

// %% [markdown]
// ## Dio 1: forEach
// Metoda `forEach` izvršava određenu funkciju za svaki element niza. Ne vraća novi niz.

// %% [markdown]
// ### Zadatak 1.
// Zadan je niz brojeva `brojevi`. Koristeći `forEach`, program treba zbrojiti sve brojeve i spremiti rezultat u varijablu `suma`.

// %%
const brojevi = [10, 20, 30, 40];
let suma = 0;

// Ovdje napiši svoj kod s forEach:


// (Ne mijenjati red ispod, služi za provjeru)
console.log("Suma niza:", suma);

// %% [markdown]
// ### Zadatak 2.
// Napisati program koji, koristeći metodu `forEach`, za svako ime u nizu `imena` ispisuje rečenicu: "Pozdrav, [ime]!".

// %%
const imena = ["Ana", "Marko", "Ivan"];

// Ovdje napiši svoj kod:

// %% [markdown]
// ### Zadatak 3.
// Napisati program koji, koristeći metodu `forEach`, prolazi kroz niz `ulazniBrojevi`. Ako je broj paran, dodaje ga u novi niz `parniBrojevi`.

// %%
const ulazniBrojevi = [1, 2, 3, 4, 5, 6, 7, 8];
let parniBrojevi = [];

// Ovdje napiši svoj kod:


console.log("Niz parnih brojeva:", parniBrojevi);

// %% [markdown]
// ### Zadatak 4.
// Napisati program koji koristi `forEach` za kreiranje objekta gdje je ključ svaka riječ u nizu, a vrijednost je duljina te riječi.

// %%
const niz = ["hello", "world", "javascript"];
let obj = {}

// Ovdje napiši svoj kod:


// Očekivani ispis: {hello: 5, world: 5, javascript: 10}

// %% [markdown]
// ---

// %% [markdown]
// ## Dio 2: Map
// Metoda `map` kreira **novi niz** transformirajući svaki element originalnog niza.

// %% [markdown]
// ### Zadatak 5.
// Napisati program koji, koristeći metodu `map`, kreira novi niz `kvadrati` koji sadrži kvadrate brojeva iz niza `baza`.

// %%
const baza = [2, 3, 4, 5];

// Ovdje napiši svoj kod (koristi const kvadrati = ...):


// Očekivan ispis: [4, 9, 16, 25]

// %% [markdown]
// ### Zadatak 6.
// Napisati program koji za zadani niz riječi, koristeći metodu `map` dodaje prefiks "auto-" svakoj riječi.

// %%
const niz = ["matic", "pilot", "nom"];

// Ovdje napiši svoj kod


// Očekivan ispis: ["auto-matic", "auto-pilot", "auto-nom"]

// %% [markdown]
// ### Zadatak 7.
// Zadan je niz objekata `korisnici`. Koristeći `map`, program treba kreirati novi niz `samoImena` koji sadrži samo stringove s imenima korisnika.

// %%
const korisnici = [
    { id: 1, ime: "Ivo", dob: 30 },
    { id: 2, ime: "Ana", dob: 25 },
    { id: 3, ime: "Marko", dob: 20 }
];

// Ovdje napiši svoj kod


// Očekivan ispis: ["Ivo", "Ana", "Marko"]

// %% [markdown]
// ### Zadatak 8.
//
// Napisati program koji će za zadani niz proizvoda, gdje svaki proizvod ima naziv i cijenu izraženu u eurima, koristeći metodu `map`, dodati PDV od 25% na cijenu svakog proizvoda i vratiti novi niz proizvoda u kojem su sve cijene izražene u eurima s uključenim PDV-om.

// %%
const proizvodi = [{naziv: 'mlijeko', cijena: 3}, {naziv: 'kruh', cijena: 2}];

// Ovdje napiši svoj kod


// Očekivan ispis: [{naziv: 'mlijeko', cijena: 3.75}, {naziv: 'kruh', cijena: 2.5}]

// %% [markdown]
// ---

// %% [markdown]
// ## Dio 3: Some
// Metoda `some` provjerava zadovoljava li **barem jedan** element niza uvjet. Vraća `true` ili `false`.

// %% [markdown]
// ### Zadatak 9.
// Napisati program koji provjerava postoji li u nizu `godine` itko tko je maloljetan (mlađi od 18) i rezultat sprema u varijablu `imaMaloljetnih`.

// %%
const godine = [20, 45, 19, 17, 30];

// Ovdje napiši svoj kod


// Očekivani ispis: false

// %% [markdown]
// ---

// %% [markdown]
// ## Dio 4: Find
// Metoda `find` vraća **prvi element** u nizu koji zadovoljava uvjet. Ako ga ne nađe, vraća `undefined`.

// %% [markdown]
// ### Zadatak 10.
// U nizu objekata `auti`, program treba pronaći **prvi** automobil kojem je boja "crna" i spremiti cijeli objekt u varijablu `crniAuto`.

// %%
const auti = [
    { marka: "BMW", boja: "plava" },
    { marka: "Audi", boja: "crna" },
    { marka: "Mercedes", boja: "crna" },
    { marka: "VW", boja: "bijela" }
];

// Ovdje napiši svoj kod


// Očekivani ispis: { marka: "Audi", boja: "crna" }
